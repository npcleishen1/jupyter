# %%
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
import openpyxl
import akshare as ak
InteractiveShell.ast_node_interactivity = "all"
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 5000
pd.options.display.float_format = lambda x: '%.5f' % x
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False
# %config InlineBackend.figure_format='svg'
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from datetime import datetime
import pymysql

# %%
DB_CONFIG = {
    "host": "192.168.133.132",  # Ubuntu的IP
    "user": "root",
    "password": "Zyice001347",    
    "charset": "utf8mb4",
}
# 初始化数据库连接
conn = pymysql.connect(**DB_CONFIG)
cursor = conn.cursor()

# 1. 创建数据库（如果不存在）
cursor.execute("CREATE DATABASE IF NOT EXISTS a_shares CHARACTER SET utf8mb4;")
conn.select_db("a_shares")

def get_stock_codes():
 
    try:
        df=ak.stock_zh_a_spot()[['代码','名称']].rename(columns={'代码':'code','名称':'name'})
        #上证代码（包含科创板）
        code_sh=df
        code_sh=code_sh[code_sh['code'].str.startswith('sh')]
        code_sh=code_sh[(~code_sh['name'].str.startswith('ST'))&(~code_sh['name'].str.startswith('*ST'))]
        code_sh['code']=code_sh['code'].str[2:]

        #深证代码（包含创业板）
        code_sz=df
        code_sz=code_sz[code_sz['code'].str.startswith('sz')]
        code_sz=code_sz[(~code_sz['name'].str.startswith('ST'))&(~code_sz['name'].str.startswith('*ST'))]
        code_sz['code']=code_sz['code'].str[2:]

        #北证代码
        code_bj=df
        code_bj=code_bj[code_bj['code'].str.startswith('bj')]
        code_bj=code_bj[(~code_bj['name'].str.startswith('ST'))&(~code_bj['name'].str.startswith('*ST'))]
        code_bj['code']=code_bj['code'].str[2:]

        #A股所有代码
        code=pd.concat([code_bj,code_sh,code_sz],ignore_index=True).drop_duplicates().sort_values(by='code',ascending=True).reset_index(drop=True)
        return code['code'].tolist()
    except Exception as e:
        print(f"获取股票列表失败: {e}")
        return []
# Out:
# 1

# %%
def fetch_and_save_stock(code):
    """爬取单只股票数据，仅当有新数据（len>0）时打印成功信息"""
    try:

        df = ak.stock_zh_a_hist(symbol=code, adjust="hfq")

        # 数据预处理
        df["日期"] = pd.to_datetime(df["日期"]).dt.date
        df.dropna(inplace=True)

        # 表名使用纯数字代码
        table_name = code

        # 判断表是否存在，不存在则创建
        cursor.execute(f"SHOW TABLES LIKE '{table_name}';")
        table_exists = cursor.fetchone() is not None

        if not table_exists:
            create_table_sql = f"""
            CREATE TABLE `{table_name}` (
                `日期` DATE NOT NULL PRIMARY KEY,
                `开盘` FLOAT,
                `收盘` FLOAT,
                `最高` FLOAT,
                `最低` FLOAT,
                `成交量` BIGINT,
                `成交额` BIGINT,
                `振幅` FLOAT,
                `涨跌幅` FLOAT,
                `涨跌额` FLOAT,
                `换手率` FLOAT
            ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4;
            """
            cursor.execute(create_table_sql)
            # 新表创建后，所有数据都是新的，无需筛选
            new_data_count = len(df)
        else:
            # 增量更新：只保留新数据
            cursor.execute(f"SELECT MAX(`日期`) FROM `{table_name}`;")
            max_date = cursor.fetchone()[0]
            if max_date:
                df = df[df["日期"] > max_date]
            new_data_count = len(df)
            if new_data_count == 0:
                # 无新数据，直接跳过（不打印成功信息）
                return

        # 批量插入新数据
        insert_sql = f"""
        INSERT IGNORE INTO `{table_name}` 
        (日期, 开盘, 收盘, 最高, 最低, 成交量, 成交额, 振幅, 涨跌幅, 涨跌额, 换手率)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        data = [tuple(row) for row in df[["日期", "开盘", "收盘", "最高", "最低", 
                                         "成交量", "成交额", "振幅", "涨跌幅", "涨跌额", "换手率"]].values]
        cursor.executemany(insert_sql, data)
        conn.commit()

        # 仅当有新数据（len>0）时打印成功信息
        if new_data_count > 0:
            print(f"股票 {code} 处理成功，新增 {new_data_count} 条数据")

    except Exception as e:
        print(f"股票 {code} 处理失败: {str(e)}")
        conn.rollback()

# %%
stock_codes = get_stock_codes()
for code in stock_codes:
    fetch_and_save_stock(code)

cursor.close()
conn.close()
# Out:
# Please wait for a moment:   0%|          | 0/68 [00:00<?, ?it/s]
# 股票 000001 处理成功，新增 8201 条数据
# 股票 000002 处理成功，新增 8216 条数据
# 股票 000006 处理成功，新增 7886 条数据
# 股票 000007 处理成功，新增 7383 条数据
# 股票 000008 处理成功，新增 7693 条数据
# 股票 000009 处理成功，新增 8112 条数据
# 股票 000010 处理成功，新增 6210 条数据
# 股票 000011 处理成功，新增 7893 条数据
# 股票 000012 处理成功，新增 8017 条数据
# 股票 000014 处理成功，新增 7903 条数据
# 股票 000016 处理成功，新增 7930 条数据
# 股票 000017 处理成功，新增 6981 条数据
# 股票 000019 处理成功，新增 7587 条数据
# 股票 000020 处理成功，新增 7561 条数据
# 股票 000021 处理成功，新增 7530 条数据
# 股票 000025 处理成功，新增 7665 条数据
# 股票 000026 处理成功，新增 7707 条数据
# 股票 000027 处理成功，新增 7605 条数据
# 股票 000028 处理成功，新增 7574 条数据
# 股票 000029 处理成功，新增 6657 条数据
# 股票 000030 处理成功，新增 6872 条数据
# 股票 000031 处理成功，新增 7422 条数据
# 股票 000032 处理成功，新增 7376 条数据
# 股票 000034 处理成功，新增 6815 条数据
# 股票 000035 处理成功，新增 6472 条数据
# 股票 000036 处理成功，新增 7328 条数据
# 股票 000037 处理成功，新增 7156 条数据
# 股票 000039 处理成功，新增 7484 条数据
# 股票 000042 处理成功，新增 7188 条数据
# 股票 000045 处理成功，新增 7246 条数据
# 股票 000048 处理成功，新增 7203 条数据
# 股票 000049 处理成功，新增 7196 条数据
# 股票 000050 处理成功，新增 7080 条数据
# 股票 000055 处理成功，新增 7020 条数据
# 股票 000056 处理成功，新增 6743 条数据
# 股票 000058 处理成功，新增 6399 条数据
# 股票 000059 处理成功，新增 6719 条数据
# 股票 000060 处理成功，新增 6816 条数据
# 股票 000061 处理成功，新增 6627 条数据
# 股票 000062 处理成功，新增 6722 条数据
# 股票 000063 处理成功，新增 6554 条数据
# 股票 000065 处理成功，新增 6368 条数据
# 股票 000066 处理成功，新增 6493 条数据
# 股票 000068 处理成功，新增 6190 条数据
# 股票 000069 处理成功，新增 6614 条数据
# 股票 000070 处理成功，新增 5857 条数据
# 股票 000078 处理成功，新增 6341 条数据
# 股票 000088 处理成功，新增 6634 条数据
# 股票 000089 处理成功，新增 6542 条数据
# 股票 000090 处理成功，新增 6170 条数据
# 股票 000096 处理成功，新增 6009 条数据
# 股票 000099 处理成功，新增 5887 条数据
# 股票 000100 处理成功，新增 4868 条数据
# 股票 000151 处理成功，新增 5974 条数据
# 股票 000153 处理成功，新增 5617 条数据
# 股票 000155 处理成功，新增 5353 条数据
# 股票 000156 处理成功，新增 4247 条数据
# 股票 000157 处理成功，新增 5874 条数据
# 股票 000158 处理成功，新增 5915 条数据
# 股票 000159 处理成功，新增 5763 条数据
# 股票 000166 处理成功，新增 2521 条数据
# 股票 000301 处理成功，新增 5803 条数据
# 股票 000333 处理成功，新增 2817 条数据
# 股票 000338 处理成功，新增 4371 条数据
# 股票 000400 处理成功，新增 6576 条数据
# 股票 000401 处理成功，新增 6799 条数据
# 股票 000402 处理成功，新增 6971 条数据
# 股票 000403 处理成功，新增 5266 条数据
# 股票 000404 处理成功，新增 6952 条数据
# 股票 000407 处理成功，新增 6783 条数据
# 股票 000408 处理成功，新增 6549 条数据
# 股票 000409 处理成功，新增 6268 条数据
# 股票 000410 处理成功，新增 6883 条数据
# 股票 000411 处理成功，新增 6558 条数据
# 股票 000415 处理成功，新增 6299 条数据
# 股票 000417 处理成功，新增 6952 条数据
# 股票 000419 处理成功，新增 6970 条数据
# 股票 000420 处理成功，新增 6896 条数据
# 股票 000421 处理成功，新增 6838 条数据
# 股票 000422 处理成功，新增 6872 条数据
# 股票 000423 处理成功，新增 6865 条数据
# 股票 000425 处理成功，新增 6854 条数据
# 股票 000426 处理成功，新增 6571 条数据
# 股票 000428 处理成功，新增 6817 条数据
# 股票 000429 处理成功，新增 6375 条数据
# 股票 000498 处理成功，新增 5489 条数据
# 股票 000501 处理成功，新增 7782 条数据
# 股票 000503 处理成功，新增 7603 条数据
# 股票 000505 处理成功，新增 7488 条数据
# 股票 000506 处理成功，新增 6896 条数据
# 股票 000507 处理成功，新增 7749 条数据
# 股票 000509 处理成功，新增 7263 条数据
# 股票 000510 处理成功，新增 7617 条数据
# 股票 000513 处理成功，新增 7396 条数据
# 股票 000514 处理成功，新增 7605 条数据
# 股票 000516 处理成功，新增 7501 条数据
# 股票 000517 处理成功，新增 6767 条数据
# 股票 000519 处理成功，新增 7435 条数据
# 股票 000520 处理成功，新增 6966 条数据
# 股票 000521 处理成功，新增 7602 条数据
# 股票 000523 处理成功，新增 7488 条数据
# 股票 000524 处理成功，新增 7448 条数据
# 股票 000525 处理成功，新增 7570 条数据
# 股票 000526 处理成功，新增 7095 条数据
# 股票 000528 处理成功，新增 7606 条数据
# 股票 000529 处理成功，新增 6729 条数据
# 股票 000530 处理成功，新增 7557 条数据
# 股票 000531 处理成功，新增 7460 条数据
# 股票 000532 处理成功，新增 7493 条数据
# 股票 000533 处理成功，新增 7380 条数据
# 股票 000534 处理成功，新增 7122 条数据
# 股票 000536 处理成功，新增 6704 条数据
# 股票 000537 处理成功，新增 7430 条数据
# 股票 000538 处理成功，新增 7433 条数据
# 股票 000539 处理成功，新增 7480 条数据
# 股票 000541 处理成功，新增 7573 条数据
# 股票 000543 处理成功，新增 7587 条数据
# 股票 000544 处理成功，新增 7471 条数据
# 股票 000545 处理成功，新增 6859 条数据
# 股票 000546 处理成功，新增 7133 条数据
# 股票 000547 处理成功，新增 7174 条数据
# 股票 000548 处理成功，新增 7584 条数据
# 股票 000550 处理成功，新增 7597 条数据
# 股票 000551 处理成功，新增 7554 条数据
# 股票 000552 处理成功，新增 7308 条数据
# 股票 000553 处理成功，新增 7234 条数据
# 股票 000554 处理成功，新增 7582 条数据
# 股票 000555 处理成功，新增 7069 条数据
# 股票 000557 处理成功，新增 6000 条数据
# 股票 000558 处理成功，新增 7225 条数据
# 股票 000559 处理成功，新增 7576 条数据
# 股票 000560 处理成功，新增 7024 条数据
# 股票 000561 处理成功，新增 6864 条数据
# 股票 000563 处理成功，新增 7459 条数据
# 股票 000564 处理成功，新增 7083 条数据
# 股票 000565 处理成功，新增 7396 条数据
# 股票 000566 处理成功，新增 7205 条数据
# 股票 000567 处理成功，新增 7448 条数据
# 股票 000568 处理成功，新增 7458 条数据
# 股票 000570 处理成功，新增 7473 条数据
# 股票 000571 处理成功，新增 7145 条数据
# 股票 000572 处理成功，新增 7437 条数据
# 股票 000573 处理成功，新增 7450 条数据
# 股票 000576 处理成功，新增 7293 条数据
# 股票 000581 处理成功，新增 6440 条数据
# 股票 000582 处理成功，新增 6776 条数据
# 股票 000586 处理成功，新增 6686 条数据
# 股票 000589 处理成功，新增 7063 条数据
# 股票 000590 处理成功，新增 6870 条数据
# 股票 000591 处理成功，新增 6936 条数据
# 股票 000592 处理成功，新增 6389 条数据
# 股票 000593 处理成功，新增 6886 条数据
# 股票 000596 处理成功，新增 6775 条数据
# 股票 000597 处理成功，新增 6951 条数据
# 股票 000598 处理成功，新增 6979 条数据
# 股票 000599 处理成功，新增 7001 条数据
# 股票 000600 处理成功，新增 6792 条数据
# 股票 000601 处理成功，新增 6872 条数据
# 股票 000603 处理成功，新增 6175 条数据
# 股票 000605 处理成功，新增 6235 条数据
# 股票 000607 处理成功，新增 6692 条数据
# 股票 000610 处理成功，新增 6782 条数据
# 股票 000612 处理成功，新增 6635 条数据
# 股票 000617 处理成功，新增 6754 条数据
# 股票 000619 处理成功，新增 6861 条数据
# 股票 000620 处理成功，新增 5582 条数据
# 股票 000623 处理成功，新增 6823 条数据
# 股票 000625 处理成功，新增 6571 条数据
# 股票 000626 处理成功，新增 6687 条数据
# 股票 000628 处理成功，新增 6419 条数据
# 股票 000629 处理成功，新增 6236 条数据
# 股票 000630 处理成功，新增 6710 条数据
# 股票 000631 处理成功，新增 6163 条数据
# 股票 000632 处理成功，新增 6875 条数据
# 股票 000633 处理成功，新增 6005 条数据
# 股票 000635 处理成功，新增 6785 条数据
# 股票 000636 处理成功，新增 6690 条数据
# 股票 000637 处理成功，新增 6870 条数据
# 股票 000639 处理成功，新增 6634 条数据
# 股票 000650 处理成功，新增 6574 条数据
# 股票 000651 处理成功，新增 6732 条数据
# 股票 000652 处理成功，新增 6664 条数据
# 股票 000655 处理成功，新增 6609 条数据
# 股票 000657 处理成功，新增 5882 条数据
# 股票 000659 处理成功，新增 6744 条数据
# 股票 000661 处理成功，新增 6822 条数据
# 股票 000663 处理成功，新增 6688 条数据
# 股票 000665 处理成功，新增 6655 条数据
# 股票 000670 处理成功，新增 4593 条数据
# 股票 000672 处理成功，新增 5266 条数据
# 股票 000676 处理成功，新增 6573 条数据
# 股票 000677 处理成功，新增 6265 条数据
# 股票 000678 处理成功，新增 6532 条数据
# 股票 000679 处理成功，新增 6687 条数据
# 股票 000680 处理成功，新增 6819 条数据
# 股票 000681 处理成功，新增 5583 条数据
# 股票 000682 处理成功，新增 6579 条数据
# 股票 000683 处理成功，新增 6666 条数据
# 股票 000685 处理成功，新增 6778 条数据
# 股票 000686 处理成功，新增 6633 条数据
# 股票 000688 处理成功，新增 5146 条数据
# 股票 000690 处理成功，新增 6790 条数据
# 股票 000692 处理成功，新增 6738 条数据
# 股票 000695 处理成功，新增 6315 条数据
# 股票 000698 处理成功，新增 6704 条数据
# 股票 000700 处理成功，新增 6713 条数据
# 股票 000701 处理成功，新增 6817 条数据
# 股票 000702 处理成功，新增 6817 条数据
# 股票 000703 处理成功，新增 6687 条数据
# 股票 000705 处理成功，新增 6767 条数据
# 股票 000707 处理成功，新增 6677 条数据
# 股票 000708 处理成功，新增 6683 条数据
# 股票 000709 处理成功，新增 6640 条数据
# 股票 000710 处理成功，新增 6452 条数据
# 股票 000712 处理成功，新增 6486 条数据
# 股票 000713 处理成功，新增 6648 条数据
# 股票 000715 处理成功，新增 6496 条数据
# 股票 000716 处理成功，新增 6247 条数据
# 股票 000717 处理成功，新增 6677 条数据
# 股票 000718 处理成功，新增 6456 条数据
# 股票 000719 处理成功，新增 5636 条数据
# 股票 000720 处理成功，新增 6500 条数据
# 股票 000721 处理成功，新增 6607 条数据
# 股票 000722 处理成功，新增 6139 条数据
# 股票 000723 处理成功，新增 6263 条数据
# 股票 000725 处理成功，新增 5820 条数据
# 股票 000726 处理成功，新增 5861 条数据
# 股票 000727 处理成功，新增 6615 条数据
# 股票 000728 处理成功，新增 6496 条数据
# 股票 000729 处理成功，新增 6735 条数据
# 股票 000731 处理成功，新增 6707 条数据
# 股票 000733 处理成功，新增 6728 条数据
# 股票 000735 处理成功，新增 6722 条数据
# 股票 000737 处理成功，新增 6729 条数据
# 股票 000738 处理成功，新增 6667 条数据
# 股票 000739 处理成功，新增 6694 条数据
# 股票 000750 处理成功，新增 5585 条数据
# 股票 000751 处理成功，新增 6303 条数据
# 股票 000753 处理成功，新增 6719 条数据
# 股票 000755 处理成功，新增 6366 条数据
# 股票 000756 处理成功，新增 6634 条数据
# 股票 000757 处理成功，新增 5063 条数据
# 股票 000758 处理成功，新增 6722 条数据
# 股票 000759 处理成功，新增 6612 条数据
# 股票 000761 处理成功，新增 6532 条数据
# 股票 000762 处理成功，新增 6656 条数据
# 股票 000766 处理成功，新增 6343 条数据
# 股票 000767 处理成功，新增 6630 条数据
# 股票 000768 处理成功，新增 6633 条数据
# 股票 000776 处理成功，新增 5883 条数据
# 股票 000777 处理成功，新增 6688 条数据
# 股票 000778 处理成功，新增 6699 条数据
# 股票 000779 处理成功，新增 6575 条数据
# 股票 000782 处理成功，新增 6632 条数据
# 股票 000783 处理成功，新增 6479 条数据
# 股票 000785 处理成功，新增 6548 条数据
# 股票 000786 处理成功，新增 6614 条数据
# 股票 000788 处理成功，新增 6578 条数据
# 股票 000789 处理成功，新增 6647 条数据
# 股票 000790 处理成功，新增 6470 条数据
# 股票 000791 处理成功，新增 6599 条数据
# 股票 000792 处理成功，新增 6156 条数据
# 股票 000795 处理成功，新增 6560 条数据
# 股票 000796 处理成功，新增 6207 条数据
# 股票 000797 处理成功，新增 6692 条数据
# 股票 000798 处理成功，新增 6493 条数据
# 股票 000799 处理成功，新增 6555 条数据
# 股票 000800 处理成功，新增 6733 条数据
# 股票 000801 处理成功，新增 6459 条数据
# 股票 000802 处理成功，新增 6421 条数据
# 股票 000803 处理成功，新增 6259 条数据
# 股票 000807 处理成功，新增 6434 条数据
# 股票 000809 处理成功，新增 6272 条数据
# 股票 000810 处理成功，新增 6117 条数据
# 股票 000811 处理成功，新增 6438 条数据
# 股票 000812 处理成功，新增 6181 条数据
# 股票 000813 处理成功，新增 6090 条数据
# 股票 000815 处理成功，新增 6130 条数据
# 股票 000816 处理成功，新增 6609 条数据
# 股票 000818 处理成功，新增 6186 条数据
# 股票 000819 处理成功，新增 6705 条数据
# 股票 000821 处理成功，新增 6317 条数据
# 股票 000822 处理成功，新增 6491 条数据
# 股票 000823 处理成功，新增 6685 条数据
# 股票 000825 处理成功，新增 6311 条数据
# 股票 000826 处理成功，新增 6316 条数据
# 股票 000828 处理成功，新增 6513 条数据
# 股票 000829 处理成功，新增 6249 条数据
# 股票 000830 处理成功，新增 6458 条数据
# 股票 000831 处理成功，新增 5974 条数据
# 股票 000833 处理成功，新增 6196 条数据
# 股票 000837 处理成功，新增 6370 条数据
# 股票 000838 处理成功，新增 6516 条数据
# 股票 000839 处理成功，新增 6525 条数据
# 股票 000848 处理成功，新增 6622 条数据
# 股票 000850 处理成功，新增 6288 条数据
# 股票 000852 处理成功，新增 6250 条数据
# 股票 000856 处理成功，新增 6409 条数据
# 股票 000858 处理成功，新增 6470 条数据
# 股票 000859 处理成功，新增 6367 条数据
# 股票 000860 处理成功，新增 6378 条数据
# 股票 000862 处理成功，新增 6043 条数据
# 股票 000863 处理成功，新增 5276 条数据
# 股票 000868 处理成功，新增 6603 条数据
# 股票 000869 处理成功，新增 5942 条数据
# 股票 000875 处理成功，新增 5326 条数据
# 股票 000876 处理成功，新增 6392 条数据
# 股票 000877 处理成功，新增 6314 条数据
# 股票 000878 处理成功，新增 6364 条数据
# 股票 000880 处理成功，新增 6330 条数据
# 股票 000881 处理成功，新增 6290 条数据
# 股票 000882 处理成功，新增 6367 条数据
# 股票 000883 处理成功，新增 6309 条数据
# 股票 000885 处理成功，新增 5883 条数据
# 股票 000886 处理成功，新增 6580 条数据
# 股票 000887 处理成功，新增 6087 条数据
# 股票 000888 处理成功，新增 6641 条数据
# 股票 000889 处理成功，新增 6195 条数据
# 股票 000890 处理成功，新增 6187 条数据
# 股票 000892 处理成功，新增 5633 条数据
# 股票 000893 处理成功，新增 5997 条数据
# 股票 000895 处理成功，新增 5882 条数据
# 股票 000897 处理成功，新增 6244 条数据
# 股票 000898 处理成功，新增 6610 条数据
# 股票 000899 处理成功，新增 6567 条数据
# 股票 000900 处理成功，新增 6164 条数据
# 股票 000901 处理成功，新增 6147 条数据
# 股票 000902 处理成功，新增 6145 条数据
# 股票 000905 处理成功，新增 6074 条数据
# 股票 000906 处理成功，新增 6083 条数据
# 股票 000910 处理成功，新增 6231 条数据
# 股票 000911 处理成功，新增 6202 条数据
# 股票 000912 处理成功，新增 5844 条数据
# 股票 000913 处理成功，新增 6239 条数据
# 股票 000915 处理成功，新增 6282 条数据
# 股票 000917 处理成功，新增 5988 条数据
# 股票 000919 处理成功，新增 6179 条数据
# 股票 000920 处理成功，新增 5909 条数据
# 股票 000921 处理成功，新增 5902 条数据
# 股票 000922 处理成功，新增 6091 条数据
# 股票 000923 处理成功，新增 6099 条数据
# 股票 000925 处理成功，新增 5566 条数据
# 股票 000926 处理成功，新增 6213 条数据
# 股票 000927 处理成功，新增 6155 条数据
# 股票 000928 处理成功，新增 6205 条数据
# 股票 000930 处理成功，新增 6091 条数据
# 股票 000931 处理成功，新增 6000 条数据
# 股票 000932 处理成功，新增 6018 条数据
# 股票 000933 处理成功，新增 6182 条数据
# 股票 000935 处理成功，新增 5849 条数据
# 股票 000936 处理成功，新增 6191 条数据
# 股票 000937 处理成功，新增 6180 条数据
# 股票 000938 处理成功，新增 5989 条数据
# 股票 000948 处理成功，新增 6082 条数据
# 股票 000949 处理成功，新增 6143 条数据
# 股票 000950 处理成功，新增 5583 条数据
# 股票 000951 处理成功，新增 5992 条数据
# 股票 000952 处理成功，新增 6033 条数据
# 股票 000953 处理成功，新增 5849 条数据
# 股票 000955 处理成功，新增 5984 条数据
# 股票 000957 处理成功，新增 6083 条数据
# 股票 000958 处理成功，新增 6008 条数据
# 股票 000959 处理成功，新增 5762 条数据
# 股票 000960 处理成功，新增 6007 条数据
# 股票 000962 处理成功，新增 5876 条数据
# 股票 000963 处理成功，新增 6013 条数据
# 股票 000965 处理成功，新增 5940 条数据
# 股票 000966 处理成功，新增 6072 条数据
# 股票 000967 处理成功，新增 5810 条数据
# 股票 000968 处理成功，新增 5804 条数据
# 股票 000969 处理成功，新增 5959 条数据
# 股票 000970 处理成功，新增 6044 条数据
# 股票 000973 处理成功，新增 5905 条数据
# 股票 000975 处理成功，新增 5577 条数据
# 股票 000977 处理成功，新增 5971 条数据
# 股票 000978 处理成功，新增 5984 条数据
# 股票 000980 处理成功，新增 5831 条数据
# 股票 000981 处理成功，新增 4948 条数据
# 股票 000983 处理成功，新增 6002 条数据
# 股票 000985 处理成功，新增 6014 条数据
# 股票 000987 处理成功，新增 5850 条数据
# 股票 000988 处理成功，新增 6017 条数据
# 股票 000989 处理成功，新增 5922 条数据
# 股票 000990 处理成功，新增 5754 条数据
# 股票 000993 处理成功，新增 5974 条数据
# 股票 000995 处理成功，新增 5159 条数据
# 股票 000997 处理成功，新增 5857 条数据
# 股票 000998 处理成功，新增 5742 条数据
# 股票 000999 处理成功，新增 5882 条数据
# 股票 001201 处理成功，新增 1028 条数据
# 股票 001202 处理成功，新增 1027 条数据
# 股票 001203 处理成功，新增 1023 条数据
# 股票 001205 处理成功，新增 1020 条数据
# 股票 001206 处理成功，新增 1017 条数据
# 股票 001207 处理成功，新增 992 条数据
# 股票 001208 处理成功，新增 991 条数据
# 股票 001209 处理成功，新增 970 条数据
# 股票 001210 处理成功，新增 966 条数据
# 股票 001211 处理成功，新增 961 条数据
# 股票 001212 处理成功，新增 947 条数据
# 股票 001213 处理成功，新增 937 条数据
# 股票 001215 处理成功，新增 939 条数据
# 股票 001216 处理成功，新增 915 条数据
# 股票 001217 处理成功，新增 924 条数据
# 股票 001218 处理成功，新增 917 条数据
# 股票 001219 处理成功，新增 913 条数据
# 股票 001222 处理成功，新增 710 条数据
# 股票 001223 处理成功，新增 634 条数据
# 股票 001225 处理成功，新增 588 条数据
# 股票 001226 处理成功，新增 751 条数据
# 股票 001227 处理成功，新增 852 条数据
# 股票 001228 处理成功，新增 785 条数据
# 股票 001229 处理成功，新增 718 条数据
# 股票 001230 处理成功，新增 734 条数据
# 股票 001231 处理成功，新增 709 条数据
# 股票 001234 处理成功，新增 856 条数据
# 股票 001236 处理成功，新增 719 条数据
# 股票 001238 处理成功，新增 689 条数据
# 股票 001239 处理成功，新增 391 条数据
# 股票 001255 处理成功，新增 680 条数据
# 股票 001256 处理成功，新增 639 条数据
# 股票 001258 处理成功，新增 726 条数据
# 股票 001259 处理成功，新增 701 条数据
# 股票 001260 处理成功，新增 592 条数据
# 股票 001266 处理成功，新增 827 条数据
# 股票 001267 处理成功，新增 891 条数据
# 股票 001268 处理成功，新增 745 条数据
# 股票 001269 处理成功，新增 680 条数据
# 股票 001277 处理成功，新增 214 条数据
# 股票 001278 处理成功，新增 578 条数据
# 股票 001279 处理成功，新增 193 条数据
# 股票 001282 处理成功，新增 527 条数据
# 股票 001283 处理成功，新增 698 条数据
# 股票 001286 处理成功，新增 556 条数据
# 股票 001287 处理成功，新增 556 条数据
# 股票 001288 处理成功，新增 906 条数据
# 股票 001289 处理成功，新增 847 条数据
# 股票 001296 处理成功，新增 867 条数据
# 股票 001298 处理成功，新增 664 条数据
# 股票 001299 处理成功，新增 664 条数据
# 股票 001300 处理成功，新增 672 条数据
# 股票 001301 处理成功，新增 622 条数据
# 股票 001306 处理成功，新增 409 条数据
# 股票 001308 处理成功，新增 813 条数据
# 股票 001309 处理成功，新增 744 条数据
# 股票 001311 处理成功，新增 585 条数据
# 股票 001313 处理成功，新增 835 条数据
# 股票 001314 处理成功，新增 594 条数据
# 股票 001316 处理成功，新增 749 条数据
# 股票 001317 处理成功，新增 880 条数据
# 股票 001318 处理成功，新增 773 条数据
# 股票 001319 处理成功，新增 779 条数据
# 股票 001322 处理成功，新增 667 条数据
# 股票 001323 处理成功，新增 750 条数据
# 股票 001324 处理成功，新增 529 条数据
# 股票 001326 处理成功，新增 414 条数据
# 股票 001328 处理成功，新增 556 条数据
# 股票 001330 处理成功，新增 710 条数据
# 股票 001331 处理成功，新增 695 条数据
# 股票 001332 处理成功，新增 688 条数据
# 股票 001333 处理成功，新增 636 条数据
# 股票 001335 处理成功，新增 69 条数据
# 股票 001336 处理成功，新增 728 条数据
# 股票 001337 处理成功，新增 581 条数据
# 股票 001338 处理成功，新增 652 条数据
# 股票 001339 处理成功，新增 713 条数据
# 股票 001356 处理成功，新增 120 条数据
# 股票 001358 处理成功，新增 384 条数据
# 股票 001359 处理成功，新增 321 条数据
# 股票 001360 处理成功，新增 556 条数据
# 股票 001366 处理成功，新增 579 条数据
# 股票 001367 处理成功，新增 556 条数据
# 股票 001368 处理成功，新增 575 条数据
# 股票 001373 处理成功，新增 521 条数据
# 股票 001376 处理成功，新增 418 条数据
# 股票 001378 处理成功，新增 422 条数据
# 股票 001379 处理成功，新增 364 条数据
# 股票 001380 处理成功，新增 533 条数据
# 股票 001382 处理成功，新增 85 条数据
# 股票 001387 处理成功，新增 370 条数据
# 股票 001388 处理成功，新增 18 条数据
# 股票 001389 处理成功，新增 318 条数据
# 股票 001390 处理成功，新增 40 条数据
# 股票 001391 处理成功，新增 137 条数据
# 股票 001395 处理成功，新增 118 条数据
# 股票 001400 处理成功，新增 62 条数据
# 股票 001696 处理成功，新增 6553 条数据
# 股票 001872 处理成功，新增 7466 条数据
# 股票 001896 处理成功，新增 6411 条数据
# 股票 001914 处理成功，新增 7261 条数据
# 股票 001965 处理成功，新增 1839 条数据
# 股票 001979 处理成功，新增 2308 条数据
# 股票 002001 处理成功，新增 5066 条数据
